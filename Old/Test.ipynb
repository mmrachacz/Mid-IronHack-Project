# %%
import pandas as pd

# %%
data = pd.read_csv('GlobalLandTemperatures_GlobalTemperatures.csv')

# %%
data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
data_northernHem = data[data.dt.str.contains('-08-')]
data_northernHem = data_northernHem[~data_northernHem.dt.str.startswith('17')]
data_northernHem = data_northernHem[~data_northernHem.dt.str.startswith('18')]
data_northernHem.reset_index(inplace=True)
data_northernHem = data_northernHem.drop(['index'], axis = 1)
data_northernHem
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0    1900-08-01                  13.816                              0.383
# 1    1901-08-01                  13.789                              0.343
# 2    1902-08-01                  13.599                              0.357
# 3    1903-08-01                  13.412                              0.377
# 4    1904-08-01                  13.459                              0.327
# ..          ...                     ...                                ...
# 111  2011-08-01                  15.012                              0.091
# 112  2012-08-01                  14.720                              0.069
# 113  2013-08-01                  14.742                              0.129
# 114  2014-08-01                  14.875                              0.115
# 115  2015-08-01                  14.755                              0.072
#
# ...

# %%
data_southernHem = data[data.dt.str.contains('-02-')]
data_southernHem = data_southernHem[~data_southernHem.dt.str.startswith('17')]
data_southernHem = data_southernHem[~data_southernHem.dt.str.startswith('18')]
data_southernHem.reset_index(inplace=True)
data_southernHem = data_southernHem.drop(['index'], axis = 1)
data_southernHem
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0    1900-02-01                   3.098                              0.416
# 1    1901-02-01                   3.092                              0.418
# 2    1902-02-01                   3.606                              0.354
# 3    1903-02-01                   3.555                              0.247
# 4    1904-02-01                   2.297                              0.348
# ..          ...                     ...                                ...
# 111  2011-02-01                   3.743                              0.067
# 112  2012-02-01                   3.628                              0.102
# 113  2013-02-01                   4.222                              0.093
# 114  2014-02-01                   3.500                              0.068
# 115  2015-02-01                   4.664                              0.121
#
# ...

# %%
data2['dt'] = pd.to_datetime(data2['dt'])
data2.dtypes
# Out:
# dt                                           datetime64[ns]
# LandAverageTemperature                              float64
# LandAverageTemperatureUncertainty                   float64
# LandMaxTemperature                                  float64
# LandMaxTemperatureUncertainty                       float64
# LandMinTemperature                                  float64
# LandMinTemperatureUncertainty                       float64
# LandAndOceanAverageTemperature                      float64
# LandAndOceanAverageTemperatureUncertainty           float64
# dtype: object

# %%
data_northernHem.to_csv('GlobalTempsAugust1900_2015north.csv', index=False)
data_southernHem.to_csv('GlobalTempsAugust1900_2015south.csv', index=False)

# %%
data3 = pd.read_csv('GlobalLandTemperatures_GlobalLandTemperaturesByCountry.csv')
data3
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
data4 = data3[data3.dt.str.contains('-08-')]
data4 = data4[~data4.dt.str.startswith('17')]
# data4 = data4[~data4.dt.str.startswith('18')]
data4.reset_index(inplace=True)
data4 = data4.drop(['index'], axis = 1)
data4
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty   Country
# 0      1800-08-01              14.850                          3.676     Åland
# 1      1801-08-01              13.313                          2.045     Åland
# 2      1802-08-01              15.951                          2.419     Åland
# 3      1803-08-01              16.712                          2.856     Åland
# 4      1804-08-01              16.009                          2.225     Åland
# ...           ...                 ...                            ...       ...
# 44845  2009-08-01              18.465                          0.489  Zimbabwe
# 44846  2010-08-01              18.260                          0.447  Zimbabwe
# 44847  2011-08-01              17.883                          0.328  Zimbabwe
# 44848  2012-08-01              18.946                          1.127  Zimbabwe
# 44849  2013-08-01              19.759                          0.717  Zimbabwe
#
# ...

# %%
dataEU = data4[data4.Country.str.contains('Austria|Belgium|Bulgaria|Croatia|Cyprus|Czech Republic|Denmark|Estonia|Finland|France|Germany|Greece|Hungary|Ireland|Italy|Latvia|Lithuania|Luxembourg|Malta|Netherlands|Poland|Portugal|Romania|Slovakia|Slovenia|Spain|Sweden')]
dataEU = dataEU[~dataEU.Country.str.contains('Europe')]
dataEU = dataEU.drop(['AverageTemperatureUncertainty'], axis = 1)
dataEU.to_csv('EU_1900_2015_AVG.csv', index=False)
dataEU
# Out:
#                dt  AverageTemperature  Country
# 2867   1800-08-01              16.700  Austria
# 2868   1801-08-01              14.413  Austria
# 2869   1802-08-01              17.882  Austria
# 2870   1803-08-01              16.198  Austria
# 2871   1804-08-01              15.149  Austria
# ...           ...                 ...      ...
# 39441  2009-08-01              14.519   Sweden
# 39442  2010-08-01              13.653   Sweden
# 39443  2011-08-01              14.027   Sweden
# 39444  2012-08-01              13.330   Sweden
# 39445  2013-08-01              14.205   Sweden
#
# [5755 rows x 3 columns]

# %%
Countries = dataEU.Country.to_list()
countries = []
for x in Countries:
    if x not in countries:
        countries.append(x)
print(countries)
# Out:
# ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4468\368196120.py in <module>
#       1 d = {name: pd.DataFrame() for name in countries}
# ----> 2 d[Austria]
#
# TypeError: unhashable type: 'DataFrame'

# %%
data4.to_csv('GlobalTempsAugust1900_2015byCountryAVG.csv', index=False)

# %%
# !pip install netcdf4 h5netcdf
# Out:
# ...
#      ---------------------------------------- 6.6/6.6 MB 6.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 171.0/171.0 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !pip install xarray
import xarray as xr
import os
DS = xr.open_dataset("HWD_national_rcp45_mean_v1.0.nc")
DS.to_dataframe().to_csv("HWD.csv")

# %%
hwd = pd.read_csv('HWD.csv')
hwd
# Out:
#            lat   lon        time  height  HWD_merged
# 0         30.1 -24.9  1986-01-01     2.0         NaN
# 1         30.1 -24.9  1987-01-01     2.0         NaN
# 2         30.1 -24.9  1988-01-01     2.0         NaN
# 3         30.1 -24.9  1989-01-01     2.0         NaN
# 4         30.1 -24.9  1990-01-01     2.0         NaN
# ...        ...   ...         ...     ...         ...
# 25457495  72.5  34.9  2081-01-01     2.0         NaN
# 25457496  72.5  34.9  2082-01-01     2.0         NaN
# 25457497  72.5  34.9  2083-01-01     2.0         NaN
# 25457498  72.5  34.9  2084-01-01     2.0         NaN
# 25457499  72.5  34.9  2085-01-01     2.0         NaN
#
# [25457500 rows x 5 columns]
