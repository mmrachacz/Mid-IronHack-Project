# %%
import pandas as pd

# %%
avg_temp_eu = pd.read_csv('EU_1900_2015_AVG.csv')
avg_temp_eu
# Out:
#               dt  AverageTemperature  Country
# 0     1800-08-01              16.700  Austria
# 1     1801-08-01              14.413  Austria
# 2     1802-08-01              17.882  Austria
# 3     1803-08-01              16.198  Austria
# 4     1804-08-01              15.149  Austria
# ...          ...                 ...      ...
# 5750  2009-08-01              14.519   Sweden
# 5751  2010-08-01              13.653   Sweden
# 5752  2011-08-01              14.027   Sweden
# 5753  2012-08-01              13.330   Sweden
# 5754  2013-08-01              14.205   Sweden
#
# [5755 rows x 3 columns]

# %%
change_temp_eu = pd.read_csv('TemperatureChangeEULast20Years.csv')
change_temp_eu
# Out:
#    Domain Code              Domain  Area Code (M49)                 Area  \
# 0           ET  Temperature change               97  European Union (27)
# 1           ET  Temperature change               97  European Union (27)
# 2           ET  Temperature change               97  European Union (27)
# 3           ET  Temperature change               97  European Union (27)
# 4           ET  Temperature change               97  European Union (27)
# ..         ...                 ...              ...                  ...
# 75          ET  Temperature change               97  European Union (27)
# 76          ET  Temperature change               97  European Union (27)
# 77          ET  Temperature change               97  European Union (27)
# 78          ET  Temperature change               97  European Union (27)
# 79          ET  Temperature change               97  European Union (27)
#
#     Element Code             Element  Months Code       Months  Year Code  \
# ...
